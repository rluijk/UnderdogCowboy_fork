# %%
from underdogcowboy import adm, gitbookdoc

# %%
# enable dialog via the adm
from underdogcowboy import adm, gitbookdoc
adm | [gitbookdoc]

file_ref = "/Users/reneluijk/projects/UnderdogCowboy/underdogcowboy/core/agent.py"
response = gitbookdoc >> f"file {file_ref}"
print(response)
+adm
# Out:
# test
# Available providers:
# 1. anthropic
# 2. google-vertex
# 3. groq
#
# Available models for anthropic:
# 1. Claude 3.5 Sonnet (Upgrade) (claude-3-5-sonnet-20241022)
# 2. Claude 3.5 Sonnet (claude-3-5-sonnet-20240620)
# 3. Claude 3 Opus (claude-3-opus-20240229)
# 4. Claude 3 Sonnet (claude-3-sonnet-20240229)
# 5. Claude 3 Haiku (claude-3-haiku-20240307)
# anthropic provider initialized successfully for model ('anthropic', 'claude-3-5-sonnet-20241022').
# Interactive mode started.
# DEBUG:root:entering request to Anthropic API
# DEBUG:root:response generated by Anthropic API
# Error: 400, {"type":"error","error":{"type":"invalid_request_error","message":"model: Input should be a valid string"}}
# Agent: Error: Empty message not processed.
# Agent: Error: Empty message not processed.
# Agent: Error: Empty message not processed.
# Agent: Error: Empty message not processed.
# Resuming script execution.
