# %%
# !pip install -e ..

# %%
import underdogcowboy

# %%
from underdogcowboy import new_language

# Use the language_agent
print(new_language)
print(new_language.content)
# Out:
# <underdogcowboy.Agent object at 0x302639f10>
# {'history': [{'role': 'user', 'text': 'What will be the benefit or benefits if we let an LLM like you invent a new language, or perhaps better, develop a new language, so that more abstract reasoning via new words and language construct can take place. Will that help in discovering new features of the model?'}, {'role': 'model', 'text': "Developing a new artificial language can potentially offer several benefits in the context of large language models (LLMs) like myself:\n\n1. Increased abstraction and expressiveness: By introducing new words and language constructs, a new language could enable more precise and concise representation of complex concepts and ideas. This could facilitate more abstract reasoning and the exploration of novel ideas that might be challenging to express using existing natural languages.\n\n2. Exploring the model's capabilities: By tasking an LLM with developing a new language from scratch, researchers could gain insights into the model's ability to create and learn new linguistic structures. This could reveal interesting aspects of the model's language understanding and generation capabilities, as well as its capacity for conceptual reasoning and creativity.\n\n3. Improving language understanding: The process of developing a new language could help the model develop a deeper understanding of language structure, syntax, and semantics. This could potentially enhance the model's performance in natural language processing tasks, such as machine translation, text generation, and language understanding.\n\n4. Facilitating human-AI communication: A new language developed by an LLM could potentially serve as an intermediary language for more efficient communication between humans and AI systems. By abstracting away from the complexities and ambiguities of natural languages, a well-designed artificial language could enable clearer and more precise information exchange between humans and AI agents.\n\n5. Exploring language evolution: Allowing an LLM to develop a new language could provide insights into the processes of language evolution and emergence. Researchers could observe how the model introduces new linguistic features, adapts existing ones, and establishes communication protocols, potentially shedding light on the fundamental principles underlying language development.\n\nHowever, it's important to note that developing a completely new language from scratch is a highly complex task, and the success of such an endeavor would depend on the model's capabilities, the training data, and the specific objectives and constraints imposed during the language development process. Additionally, there might be challenges related to interpretability, adoption, and the potential for unintended consequences or biases introduced by the model.\n\nUltimately, the benefits of allowing an LLM to develop a new language would need to be carefully weighed against the potential risks and practical considerations, and any such efforts should be undertaken with appropriate safeguards and ethical considerations in mind."}, {'role': 'user', 'text': 'Can you give an example of a new word, that is a new abstraction?'}, {'role': 'model', 'text': 'Sure, here\'s an example of a new hypothetical word that could represent an abstract concept:\n\n"Qualia" (pronounced KWAH-lee-ah)\n\nDefinition: The ineffable essence of subjective conscious experience, encompassing the qualitative aspects of perception, emotion, and thought that cannot be fully captured or expressed through language or objective description.\n\nThis word could be used to refer to the fundamental, first-person nature of consciousness and the intrinsic qualities of subjective experiences that seem to elude complete verbalization or objective measurement. It captures the idea that there is an inherent "what-it-is-like" aspect to conscious states, which cannot be fully conveyed or understood from a third-person perspective.\n\nSome example usages:\n\n1. "The qualia of tasting  ...

# %%
from underdogcowboy import commit_promo
print(commit_promo.content)
# Out:
# {'history': [{'role': 'user', 'text': 'File sent: /Users/reneluijk/obsidian_vaults/zk_2024/Linked-in promo post on commit.md\n\nFile Content:\n\nCreate a LinkedIn post for the open-source library Underdogcowboy (UC) based on recent code updates. Follow these guidelines:\n\n1. Start with a friendly, Western-themed greeting using the 🤠 emoji.\n\n2. Mention that the UC team has been working on updates.\n\n3. Highlight 2-3 key improvements or new features from recent commits. Use emoji to emphasize each point:\n   - 🔧 for technical improvements or bug fixes\n   - 🎭 for user interface or experience enhancements\n   - 🧠 for AI-related updates or philosophical aspects\n\n4. If there\'s a code snippet to showcase, include it using triple backticks and specify the language.\n\n5. Reinforce UC\'s philosophy: letting AI agents work freely while maintaining human oversight, and adapting to evolving AI capabilities.\n\n6. End with an encouraging call-to-action, using Western slang.\n\n7. Include links to the GitHub repository and PyPI page.\n\n8. Add installation instructions via pip.\n\n9. Conclude with relevant hashtags: #OpenSource #AI #UnderdogCowboy\n\n10. Keep the overall tone playful and enthusiastic, using Western-themed metaphors and expressions throughout.\n\n11. Limit the post to 3-4 short paragraphs for readability on LinkedIn.\n\n\n---- example post 1 ----\n\n🤠 Howdy, partners! The Underdogcowboy (UC) posse\'s been busy wranglin\' some code, and we\'ve got some mighty fine updates to share!\n\n🔧 We\'ve tightened the reins on our package structure, making it easier than ever to saddle up with UC. Now you can import our trusty steeds with a simple:\n\n```python\nfrom underdogcowboy import ConfigManager, DialogManager, ModelManager\n```\n\n🎭 Our DialogManager and CommandProcessor got a shiny new coat of paint too! We\'ve streamlined message handling, making your AI interactions smoother than a tumbleweed rollin\' across the prairie.\n\n🧠 Remember, UC\'s all about lettin\' your AI agents roam free while keepin\' a watchful eye. As AI keeps evolvin\', we\'re makin\' sure UC evolves right alongside it, compressin\' complex tasks into simple operations.\n\nReady to ride the AI frontier? Giddy up and give UC a try! 🐎💨\n\nOn Github: https://github.com/Synestheticminds/UnderdogCowboy\nPyPi: https://pypi.org/project/underdogcowboy/\npip install underdogcowboy\n\n\n#OpenSource #AI #UnderdogCowboy\n\n---- example post 2 ----\n\n🤠 Howdy, AI wranglers! The Underdogcowboy (UC) posse\'s been burnin\' the midnight oil, and we\'ve rustled up some mighty fine updates for y\'all!\n\n🔧 We\'ve tightened the reins on our model management, introducin\' the new \'switch-model\' (swm) command. Now you can change your AI steed mid-gallop, adaptin\' to whatever the digital frontier throws your way! We\'ve also fixed up our global model reference, makin\' sure your posse stays in perfect harmony.\n\n🎭 The user experience got a fresh coat of paint too! We\'ve smoothed out the edges on input handlin\' in our interactive phase, makin\' your journey through AI country smoother than a tumbleweed rollin\' across the prairie.\n\nRemember, partners, UC\'s all about lettin\' your AI agents roam free while keepin\' a watchful eye. As AI keeps evolvin\', we\'re makin\' sure UC evolves right alongside it, compressin\' complex tasks into simple operations. So saddle up and give these updates a spin – your AI adventures are about to get a whole lot more excitin\'!\n\nReady to ride the AI frontier? Git along little dogies and rustle up UC for yourself!\n\nGitHub: https://github.com/Synestheticminds/UnderdogCowboy\nPyPI: https://pypi.org/project/underdogcowboy/\nInstall: `pip install underdogcowboy`\n\n#OpenSource #AI #UnderdogCowboy\n\n--- example post 3 ---\n\n🤠 Howdy, AI enthusiasts! The Underdogcowboy (UC) gang\'s been busier than a one-armed paper hanger, and we\'ve got some rootin\' tootin\' updates to share!\n\n🔧 We\'ve tightened up our corral, makin\' sure no empt ...
